# %%
import numpy as np

import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
pd.set_option('display.max_rows',1000)

pd.set_option('display.max_columns',1000)

pd.set_option('display.max_colwidth',1000)

pd.set_option('display.width',1000)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# # HEATMAP

# %%
tips.head().corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.791002  0.166315
# tip           0.791002  1.000000  0.475753
# size          0.166315  0.475753  1.000000

# %%
tc = tips.head().corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.791002  0.166315
# tip           0.791002  1.000000  0.475753
# size          0.166315  0.475753  1.000000

# %%
sns.heatmap(tc)

# %%
sns.heatmap(tc, annot = True, cmap = 'autumn')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp = flights.pivot_table(index = 'month' ,columns = 'year',values = 'passengers')

# %%
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# January     112   115   145   171   196   204   242   284   315   340   360   417
# February    118   126   150   180   196   188   233   277   301   318   342   391
# March       132   141   178   193   236   235   267   317   356   362   406   419
# April       129   135   163   181   235   227   269   313   348   348   396   461
# May         121   125   172   183   229   234   270   318   355   363   420   472
# June        135   149   178   218   243   264   315   374   422   435   472   535
# July        148   170   199   230   264   302   364   413   465   491   548   622
# August      148   170   199   242   272   293   347   405   467   505   559   606
# September   136   158   184   209   237   259   312   355   404   404   463   508
# October     119   133   162   191   211   229   274   306   347   359   407   461
# ...

# %%
sns.heatmap(fp, cmap = 'magma', linecolor = 'green', linewidth = 1)

# %% [markdown]
# # CLUSTER PLOT

# %%
sns.clustermap(fp)

# %%
sns.clustermap(fp, cmap = 'coolwarm', standard_scale = 1)

# %%
flight = sns.load_dataset('flights')
tip = sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flight.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tip.pivot_table(index = 'sex', columns = 'day', values = 'total_bill')
# Out:
# day          Thur        Fri        Sat        Sun
# sex
# Male    18.714667  19.857000  20.802542  21.887241
# Female  16.715312  14.145556  19.680357  19.872222

# %%
 fp1 = flight.pivot_table(index = 'year',columns = 'month',values = 'passengers')

# %%
sns.heatmap(fp1,cmap='autumn',linecolor='black',linewidths=2)

# %%
sns.clustermap(fp , cmap = 'autumn', standard_scale=1)

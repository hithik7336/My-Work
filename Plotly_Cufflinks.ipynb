# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.5.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns = 'A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0  -1.905221  0.655290 -1.604111  0.978626
# 1  -1.762258  1.209653  2.463447 -1.538981
# 2   2.077825 -0.153442 -1.730696  0.257104
# 3   0.385374  0.238687  0.612635  1.128825
# 4   0.493692  2.549978  0.430510 -1.783720
# ..       ...       ...       ...       ...
# 95  0.924504  0.068512 -1.729827  1.829339
# 96 -0.067190 -1.290087  0.117028  1.008636
# 97  1.317615  0.291448 -0.253054 -0.471843
# 98  1.195568 -1.888623  0.587805  1.106905
# 99 -0.056906 -1.253465 -0.285201 -1.042166
#
# [100 rows x 4 columns]

# %%
df2  = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="703e1dcd-59e7-4bda-8d62-ef0543c8723a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("703e1dcd-59e7-4bda-8d62-ef0543c8723a")) {
#                     Plotly.newPlot(
#                         '703e1dcd-59e7-4bda-8d62-ef0543c8723a',
# ...

# %%
df.iplot(kind = 'scatter', x='A', y='B',mode = 'markers',
        size = 20)
# Out:
# <div>
#
#
#             <div id="14b530e8-1a4e-47c4-b3b3-4d4a4c55f132" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("14b530e8-1a4e-47c4-b3b3-4d4a4c55f132")) {
#                     Plotly.newPlot(
#                         '14b530e8-1a4e-47c4-b3b3-4d4a4c55f132',
# ...

# %%
df2.iplot(kind = 'bar',  x='Category', y='Values')
# Out:
# <div>
#
#
#             <div id="b2b94a09-9b03-4d66-8866-bf4dec711090" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b2b94a09-9b03-4d66-8866-bf4dec711090")) {
#                     Plotly.newPlot(
#                         'b2b94a09-9b03-4d66-8866-bf4dec711090',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.iplot(kind = 'box')
# Out:
# <div>
#
#
#             <div id="a3416734-f79c-4b25-afcc-887985bcba97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a3416734-f79c-4b25-afcc-887985bcba97")) {
#                     Plotly.newPlot(
#                         'a3416734-f79c-4b25-afcc-887985bcba97',
# ...

# %%
df3  = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]} )

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind = 'surface',colorscale = 'rdylbu')
# Out:
# <div>
#
#
#             <div id="5c7e88a6-83e4-41cf-ae45-987db4956ebc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c7e88a6-83e4-41cf-ae45-987db4956ebc")) {
#                     Plotly.newPlot(
#                         '5c7e88a6-83e4-41cf-ae45-987db4956ebc',
# ...

# %%
df['A'].iplot(kind = 'hist')
# Out:
# <div>
#
#
#             <div id="b5c6a30e-c52c-4f6b-91fe-76a9fdbfdd0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b5c6a30e-c52c-4f6b-91fe-76a9fdbfdd0b")) {
#                     Plotly.newPlot(
#                         'b5c6a30e-c52c-4f6b-91fe-76a9fdbfdd0b',
# ...

# %%
df.iplot(kind = 'hist')
# Out:
# <div>
#
#
#             <div id="9f742014-9db0-4cfc-8f3c-495190d6522d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f742014-9db0-4cfc-8f3c-495190d6522d")) {
#                     Plotly.newPlot(
#                         '9f742014-9db0-4cfc-8f3c-495190d6522d',
# ...

# %%
df[['A','B']].iplot(kind = 'spread')
# Out:
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:851: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="3f2176df-05a5-43fb-b6b9-2e6f714959fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f2176df-05a5-43fb-b6b9-2e6f714959fc")) {
#                     Plotly.newPlot(
#                         '3f2176df-05a5-43fb-b6b9-2e6f714959fc',
# ...

# %%
df.iplot(kind = 'bubble', x='A', y='B',size = 'C')
# Out:
# <div>
#
#
#             <div id="beec0a1b-9237-41df-85ec-92cef7a88577" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("beec0a1b-9237-41df-85ec-92cef7a88577")) {
#                     Plotly.newPlot(
#                         'beec0a1b-9237-41df-85ec-92cef7a88577',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="55ab31f6-7724-4f90-aa0b-20366681f06f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("55ab31f6-7724-4f90-aa0b-20366681f06f")) {
#                     Plotly.newPlot(
#                         '55ab31f6-7724-4f90-aa0b-20366681f06f',
# ...

# %% [markdown]
# # PLOTLY & CUFFLINKS PRACTICE

# %%
import numpy as np

import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.randint(1,1000,(100,4)), columns = 'A B C D'.split())

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df1.head()
# Out:
#      A    B    C    D
# 0  599  973  424  785
# 1  239  792  375   25
# 2  546    1  688  317
# 3   42  584  160  266
# 4  427  737  820  120

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df1.iplot()
# Out:
# <div>
#
#
#             <div id="ca123ddd-3562-477f-8e52-165c40ad05d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ca123ddd-3562-477f-8e52-165c40ad05d0")) {
#                     Plotly.newPlot(
#                         'ca123ddd-3562-477f-8e52-165c40ad05d0',
# ...

# %%
df1.iplot(kind = 'scatter', x='A', y='B', mode = 'markers')
# Out:
# <div>
#
#
#             <div id="4f237190-0341-4e84-8d07-e580a2904329" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4f237190-0341-4e84-8d07-e580a2904329")) {
#                     Plotly.newPlot(
#                         '4f237190-0341-4e84-8d07-e580a2904329',
# ...

# %%
df2.iplot(kind = 'scatter', x='Category', y='Values', mode = 'markers')
# Out:
# <div>
#
#
#             <div id="c9b6f440-a9fb-4f09-91df-0cbc56bf552a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c9b6f440-a9fb-4f09-91df-0cbc56bf552a")) {
#                     Plotly.newPlot(
#                         'c9b6f440-a9fb-4f09-91df-0cbc56bf552a',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name": "Values", "text": "", "type": "scatter", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df1.iplot(kind ='box')
# Out:
# <div>
#
#
#             <div id="1f4db81f-e4c2-45d9-95b8-e945baa43835" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1f4db81f-e4c2-45d9-95b8-e945baa43835")) {
#                     Plotly.newPlot(
#                         '1f4db81f-e4c2-45d9-95b8-e945baa43835',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],
                    'y':[10,20,30,10,20],
                    'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  10  2
# 4  5  20  1

# %%
df3.iplot(kind = 'surface')
# Out:
# <div>
#
#
#             <div id="372a13db-3a9c-4ef0-be7a-50dd0a6db5fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("372a13db-3a9c-4ef0-be7a-50dd0a6db5fd")) {
#                     Plotly.newPlot(
#                         '372a13db-3a9c-4ef0-be7a-50dd0a6db5fd',
# ...

# %%
df1['A'].iplot(kind = 'hist')
# Out:
# <div>
#
#
#             <div id="d87e995c-c72a-4cfd-bde4-e0644a8d4d6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d87e995c-c72a-4cfd-bde4-e0644a8d4d6a")) {
#                     Plotly.newPlot(
#                         'd87e995c-c72a-4cfd-bde4-e0644a8d4d6a',
# ...

# %%
df1['A'].iplot(kind = 'bar')
# Out:
# <div>
#
#
#             <div id="009c18e6-0743-4206-bce8-93bd3744e7d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("009c18e6-0743-4206-bce8-93bd3744e7d4")) {
#                     Plotly.newPlot(
#                         '009c18e6-0743-4206-bce8-93bd3744e7d4',
# ...

# %%
df4 = pd.DataFrame(data = {'StarBucks':list(np.random.randint(50,100,5)),
                    'Apple':list(np.random.randint(100,500,5)),
                    'NKe':list(np.random.randint(100,200,5)),
                    'Tesla':list(np.random.randint(900,1000,5)),
                    'Infy.Bo':list(np.random.randint(500,1000,5))},
                   index = 'Monday Tuesady Wednesday Thursday Friday'.split())

# %%
df4
# Out:
#            StarBucks  Apple  NKe  Tesla  Infy.Bo
# Monday            72    361  167    966      961
# Tuesady           78    192  182    943      683
# Wednesday         98    187  156    997      758
# Thursday          99    173  105    934      500
# Friday            81    272  133    926      711

# %%
df4.iplot(kind = 'spread')
# Out:
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="a3225656-31cb-40c6-ad50-07e695a43240" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a3225656-31cb-40c6-ad50-07e695a43240")) {
#                     Plotly.newPlot(
#                         'a3225656-31cb-40c6-ad50-07e695a43240',
# ...

# %%
df4[['Tesla','NKe']].iplot(kind = 'spread')
# Out:
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:851: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="a0de7c96-6c3a-45d0-8d1c-f4d277cd76b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a0de7c96-6c3a-45d0-8d1c-f4d277cd76b4")) {
#                     Plotly.newPlot(
#                         'a0de7c96-6c3a-45d0-8d1c-f4d277cd76b4',
# ...

# %%
df1
# Out:
#       A    B    C    D
# 0   599  973  424  785
# 1   239  792  375   25
# 2   546    1  688  317
# 3    42  584  160  266
# 4   427  737  820  120
# ..  ...  ...  ...  ...
# 95  176   48  422  820
# 96  837  550  800  490
# 97  119  967  541  960
# 98  673  508  913  963
# 99  713  607  216  225
#
# [100 rows x 4 columns]

# %%
df4.index
# Out:
# Index(['Monday', 'Tuesady', 'Wednesday', 'Thursday', 'Friday'], dtype='object')

# %%
df4.columns
# Out:
# Index(['StarBucks', 'Apple', 'NKe', 'Tesla', 'Infy.Bo'], dtype='object')

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="1058f8ca-ccdd-49da-ad05-f129f641b6be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1058f8ca-ccdd-49da-ad05-f129f641b6be")) {
#                     Plotly.newPlot(
#                         '1058f8ca-ccdd-49da-ad05-f129f641b6be',
# ...

# %%
df1.iplot(kind = 'bubble', x='A', y='B',size = 'C')
# Out:
# <div>
#
#
#             <div id="eaddb9a7-cec1-43d6-95cc-ef5a7528102c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eaddb9a7-cec1-43d6-95cc-ef5a7528102c")) {
#                     Plotly.newPlot(
#                         'eaddb9a7-cec1-43d6-95cc-ef5a7528102c',
# ...

# %%
df4
# Out:
#            StarBucks  Apple  NKe  Tesla  Infy.Bo
# Monday            72    361  167    966      961
# Tuesady           78    192  182    943      683
# Wednesday         98    187  156    997      758
# Thursday          99    173  105    934      500
# Friday            81    272  133    926      711

# %%
df4.iplot(kind  = 'bar')
# Out:
# <div>
#
#
#             <div id="c680074a-3436-426b-a1cc-1afc64f98d52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c680074a-3436-426b-a1cc-1afc64f98d52")) {
#                     Plotly.newPlot(
#                         'c680074a-3436-426b-a1cc-1afc64f98d52',
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
stocks = pd.DataFrame(data = {'Monday':[89,12197,41681,740,68,326],
                              'Tuesday':[89,12211,41792,728,67,325],
                              'Wednesday':[89,12010,41399,836,66,326],
                              'Thursday':[90,12206,41148,771,67,326],
                              'Friday':[89,12155,41578,780,69,323],
                              'Saturday':[90,12187,41668,765,68,322]},
                     index = 'Starbucks Nifty Sensex Tesla BMW Apple'.split())

# %%
stocks
# Out:
#            Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# Starbucks      89       89         89        90      89        90
# Nifty       12197    12211      12010     12206   12155     12187
# Sensex      41681    41792      41399     41148   41578     41668
# Tesla         740      728        836       771     780       765
# BMW            68       67         66        67      69        68
# Apple         326      325        326       326     323       322

# %%
stocks['High'] = [90.50, 12246.70, 41702.36, 818.00, 67.16, 326.22]

# %%
stocks['Low'] = [88.27, 12091.20, 41183.13, 735.00, 66.47, 323.35]

# %%
stocks['Open'] = [88.50, 12190.15, 41510.19, 741.84, 66.50, 324.19]

# %%
stocks
# Out:
#            Monday  Tuesday  Wednesday  Thursday  Friday  Saturday      High  \
# Starbucks      89       89         89        90      89        90     90.50
# Nifty       12197    12211      12010     12206   12155     12187  12246.70
# Sensex      41681    41792      41399     41148   41578     41668  41702.36
# Tesla         740      728        836       771     780       765    818.00
# BMW            68       67         66        67      69        68     67.16
# Apple         326      325        326       326     323       322    326.22
#
#                 Low      Open
# Starbucks     88.27     88.50
# Nifty      12091.20  12190.15
# Sensex     41183.13  41510.19
# Tesla        735.00    741.84
# BMW           66.47     66.50
# Apple        323.35    324.19

# %%
stocks.iplot(kind = 'spread')
# Out:
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:851: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="bdc2e9f0-d26b-4730-8121-830679862a49" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bdc2e9f0-d26b-4730-8121-830679862a49")) {
#                     Plotly.newPlot(
#                         'bdc2e9f0-d26b-4730-8121-830679862a49',
# ...

# %%
stocks.iplot(kind = 'bar')
# Out:
# <div>
#
#
#             <div id="af5639a9-54eb-4c75-9097-a3c873a67305" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("af5639a9-54eb-4c75-9097-a3c873a67305")) {
#                     Plotly.newPlot(
#                         'af5639a9-54eb-4c75-9097-a3c873a67305',
# ...

# %%
stocks.columns
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'High', 'Low', 'Open'],
#       dtype='object')

# %%
stocks[['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']].iplot(kind = 'spread')
# Out:
# <div>
#
#
#             <div id="54034612-554d-43f0-9e25-f827a0197df3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54034612-554d-43f0-9e25-f827a0197df3")) {
#                     Plotly.newPlot(
#                         '54034612-554d-43f0-9e25-f827a0197df3',
# ...

# %%
df4 = pd.DataFrame(data = {'Day':'Monday Tuesady Wednesday Thursday Friday'.split(),
                    'StarBucks':list(np.random.randint(50,100,5)),
                    'Apple':list(np.random.randint(100,500,5)),
                    'NKe':list(np.random.randint(100,200,5)),
                    'Tesla':list(np.random.randint(900,1000,5)),
                    'Infy.Bo':list(np.random.randint(500,1000,5)),
                          },
                   index = np.arange(1,6,1))

# %%
df4
# Out:
#          Day  StarBucks  Apple  NKe  Tesla  Infy.Bo
# 1     Monday         74    391  118    916      811
# 2    Tuesady         85    436  130    928      649
# 3  Wednesday         61    326  197    947      548
# 4   Thursday         53    103  176    945      621
# 5     Friday         86    287  181    935      935

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.read_csv('df1', index_col=0 )
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1.iplot(kind  = 'scatter')
# Out:
# <div>
#
#
#             <div id="31af1b56-31af-486e-b1ca-d0d138a389b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("31af1b56-31af-486e-b1ca-d0d138a389b9")) {
#                     Plotly.newPlot(
#                         '31af1b56-31af-486e-b1ca-d0d138a389b9',
# ...

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.iplot(kind = 'scatter', mode= 'markers' )
# Out:
# <div>
#
#
#             <div id="3497f3d5-63d5-47da-b703-664601bd5b16" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3497f3d5-63d5-47da-b703-664601bd5b16")) {
#                     Plotly.newPlot(
#                         '3497f3d5-63d5-47da-b703-664601bd5b16',
# ...

# %%
df2.iplot(kind = 'bar')
# Out:
# <div>
#
#
#             <div id="a1fe31d4-37ee-47ec-9949-76d446935aa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a1fe31d4-37ee-47ec-9949-76d446935aa4")) {
#                     Plotly.newPlot(
#                         'a1fe31d4-37ee-47ec-9949-76d446935aa4',
# ...

# %%
df2.iplot(kind = 'hist')
# Out:
# <div>
#
#
#             <div id="8f3fa993-5b20-4613-b1b9-91ecad848bca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8f3fa993-5b20-4613-b1b9-91ecad848bca")) {
#                     Plotly.newPlot(
#                         '8f3fa993-5b20-4613-b1b9-91ecad848bca',
# ...

# %%
df2.iplot(kind = 'area')
# Out:
# <div>
#
#
#             <div id="39fe172c-f8cc-480b-ad12-74ee252b5955" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("39fe172c-f8cc-480b-ad12-74ee252b5955")) {
#                     Plotly.newPlot(
#                         '39fe172c-f8cc-480b-ad12-74ee252b5955',
# ...

# %%
df2.iplot(kind = 'box')
# Out:
# <div>
#
#
#             <div id="d1d732c5-fd8a-4fcd-bcea-2b08f0d1f830" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d1d732c5-fd8a-4fcd-bcea-2b08f0d1f830")) {
#                     Plotly.newPlot(
#                         'd1d732c5-fd8a-4fcd-bcea-2b08f0d1f830',
# ...

# %%
df2.iplot(kind = 'spread')
# Out:
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# D:\Anaconda\lib\site-packages\cufflinks\plotlytools.py:851: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="e31fb714-e6c0-4587-b180-a058462dbe53" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e31fb714-e6c0-4587-b180-a058462dbe53")) {
#                     Plotly.newPlot(
#                         'e31fb714-e6c0-4587-b180-a058462dbe53',
# ...

# %%
df2.iplot(kind = 'surface')
# Out:
# <div>
#
#
#             <div id="d95564d9-a275-492f-b64b-905df6000139" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d95564d9-a275-492f-b64b-905df6000139")) {
#                     Plotly.newPlot(
#                         'd95564d9-a275-492f-b64b-905df6000139',
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('df1' , index_col = 0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins = 30)

# %%
df1['A'].plot(kind = 'hist',bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha = 0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked = True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1.plot.scatter(x = 'A',y = 'B', c='C', cmap = 'coolwarm', s= df1['C']*100)
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a', y='b',gridsize = 25)

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.density()

# %% [markdown]
# # PANDAS DATA VIZ PRACTICE

# %%
df1 = pd.read_csv('df1', index_col = 0)
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
Tip_Bill = pd.DataFrame(data = {'Bill':list(np.random.randint(400,500,20)),
                                'Tip':list(np.random.randint(10,20,20))},
                        index = np.arange(0,20,1))

# %%
Tip_Bill['Total'] = Tip_Bill['Bill'] + Tip_Bill['Tip']

# %%
Tip_Bill
# Out:
#     Bill  Tip  Total
# 0    411   10    421
# 1    406   17    423
# 2    436   18    454
# 3    466   17    483
# 4    461   14    475
# 5    467   15    482
# 6    402   13    415
# 7    447   18    465
# 8    400   14    414
# 9    450   11    461
# 10   470   19    489
# 11   416   17    433
# 12   451   14    465
# 13   494   19    513
# 14   495   17    512
# 15   482   10    492
# 16   455   14    469
# 17   444   18    462
# 18   478   10    488
# 19   471   17    488

# %%
print( Tip_Bill['Bill'].max() , Tip_Bill['Tip'].max())
# Out:
# 495 19

# %%
print( Tip_Bill['Bill'].min() , Tip_Bill['Tip'].min())
# Out:
# 400 10

# %%
# AREA PLOT

# %%
Tip_Bill['Bill'].plot.area(color = 'red')

# %%
Tip_Bill['Tip'].plot.area(color = 'green')

# %%
Tip_Bill['Total'].plot.area(color = 'pink')

# %%
Tip_Bill['Total'].max(), Tip_Bill['Total'].min()
# Out:
# (513, 414)

# %%
Tip_Bill.plot.area()

# %%
# BAR PLOT

# %%
Tip_Bill['Tip'].plot.bar(color = 'red')

# %%
Tip_Bill['Bill'].plot.bar(color = 'green')

# %%
Tip_Bill['Total'].plot.bar(color = 'black')

# %%
Tip_Bill.plot.bar(figsize = (12,8))

# %%
# HISTOGRAM

# %%
Tip_Bill['Bill'].plot.hist(color = 'red')

# %%
Tip_Bill['Tip'].plot.hist(color = 'green')

# %%
Tip_Bill['Total'].plot.hist()

# %%
Tip_Bill.plot.hist()

# %%
# LINE PLOT

# %%
Tip_Bill['Total'].plot.line()

# %%
Tip_Bill['Bill'].plot.line()

# %%
Tip_Bill['Tip'].plot.line()

# %%
Tip_Bill.plot.line()

# %%
# BOX PLOT

# %%
print (Tip_Bill['Total'].describe(), Tip_Bill['Tip'].describe(), Tip_Bill['Bill'].describe())
# Out:
# count     20.000000
# mean     465.200000
# std       30.413986
# min      414.000000
# 25%      448.750000
# 50%      467.000000
# 75%      488.000000
# max      513.000000
# Name: Total, dtype: float64 count    20.000000
# mean     15.100000
# std       3.059068
# min      10.000000
# 25%      13.750000
# 50%      16.000000
# 75%      17.250000
# max      19.000000
# Name: Tip, dtype: float64 count     20.000000
# mean     450.100000
# std       29.876764
# min      400.000000
# 25%      431.000000
# 50%      453.000000
# 75%      470.250000
# max      495.000000
# Name: Bill, dtype: float64

# %%
Tip_Bill['Tip'].plot.box()

# %%
Tip_Bill['Total'].plot.box()

# %%
Tip_Bill['Bill'].plot.box()

# %%
Tip_Bill.plot.scatter(x='Tip', y= 'Total')

# %%
Tip_Bill.plot.hexbin(x='Tip', y='Total', C = 2)

# %%
Tip_Bill['Tip'].plot.pie()

# %%
Tip_Bill.plot.density()

# %%
Tip_Bill.plot.kde()

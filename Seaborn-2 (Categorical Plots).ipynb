# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)
pd.set_option('display.max_colwidth',1000)
pd.set_option('display.width',1000)

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import seaborn as sns

# %%
tips
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
tips[tips['day']=='Thur']['total_bill'].max()
# Out:
# 43.11

# %%
# Distribution Plots

# %%
# distplot jointplot rugplot kdeplot pairplot

# %%
# distplot jointplot rugplot pairplot kdeplot

# %%
# Categorical Plots

# %%
# barplot countplot boxplot violinplot stripplot swarmpplot factorplot

# %%
# barplot countplot boxplot violinplot swarmpplot stripplot factorplot

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips_data.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips_data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(x='day' ,y= 'total_bill' ,data= tips_data ,hue='sex')

# %%
sns.countplot(x='sex',data=tips_data)

# %%
tips_datadata
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
sns.barplot(x = 'day' ,y = 'tip' ,hue = 'sex', data = tips_data)

# %%
tips_data_10 = tips_data.head(11)

# %%
tips_data_10
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2

# %%
sns.barplot(x='sex' ,y='tip',data=tips_data_10, hue='day')

# %%
tips_data_10[tips_data_10['tip'] == tips_data_10['tip'].max()]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 5       25.29  4.71  Male     No  Sun  Dinner     4

# %%
tips_data_10[tips_data_10['tip'] == tips_data_10['tip'].min()]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
tips_data_10[(tips_data_10['tip'] == 4.71) & (tips_data_10['sex'] == 'Male')]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 5       25.29  4.71  Male     No  Sun  Dinner     4

# %%
tips_data_10[(tips_data_10['sex'] == 'Male') & (tips_data_10['total_bill'] == 25.29)]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 5       25.29  4.71  Male     No  Sun  Dinner     4

# %%
5 | 6
# Out:
# 7

# %%
5 & 6
# Out:
# 4

# %%
tips_data_10[(tips_data_10['sex'] == 'Male') & (tips_data_10['total_bill'] == 9)]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips_data_10[(tips_data_10['sex'] == 'Male') | (tips_data_10['total_bill'] == 9)]
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 1        10.34  1.66  Male     No  Sun  Dinner     3
# 2        21.01  3.50  Male     No  Sun  Dinner     3
# 3        23.68  3.31  Male     No  Sun  Dinner     2
# 5        25.29  4.71  Male     No  Sun  Dinner     4
# 6         8.77  2.00  Male     No  Sun  Dinner     2
# 7        26.88  3.12  Male     No  Sun  Dinner     4
# 8        15.04  1.96  Male     No  Sun  Dinner     2
# 9        14.78  3.23  Male     No  Sun  Dinner     2
# 10       10.27  1.71  Male     No  Sun  Dinner     2

# %%
sns.countplot(x = 'sex', data = tips_data_10, hue = 'day')

# %%
tips_data_10
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2

# %%
tips_data_10.describe()
# Out:
#        total_bill        tip       size
# count   11.000000  11.000000  11.000000
# mean    17.967273   2.710909   2.727273
# std      6.637084   1.108679   0.904534
# min      8.770000   1.010000   2.000000
# 25%     12.560000   1.835000   2.000000
# 50%     16.990000   3.120000   2.000000
# 75%     24.135000   3.405000   3.500000
# max     26.880000   4.710000   4.000000

# %%
tips_data_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  11 non-null     float64
#  1   tip         11 non-null     float64
#  2   sex         11 non-null     category
#  3   smoker      11 non-null     category
#  4   day         11 non-null     category
#  5   time        11 non-null     category
#  6   size        11 non-null     int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 916.0 bytes

# %%
tips_data_10
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2

# %%
len(tips_data_10[tips_data_10['sex']=='Male'].index)
# Out:
# 9

# %%
len(tips_data_10[tips_data_10['sex']=='Female'].index)
# Out:
# 2

# %%
plot1 = sns.boxplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')

# %%
tips_data_10.describe()
# Out:
#        total_bill        tip       size
# count   11.000000  11.000000  11.000000
# mean    17.967273   2.710909   2.727273
# std      6.637084   1.108679   0.904534
# min      8.770000   1.010000   2.000000
# 25%     12.560000   1.835000   2.000000
# 50%     16.990000   3.120000   2.000000
# 75%     24.135000   3.405000   3.500000
# max     26.880000   4.710000   4.000000

# %%
tips_data_10[(tips_data_10['sex'] == 'Male') & (tips_data_10['total_bill'] == tips_data_10['total_bill'].max())]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 7       26.88  3.12  Male     No  Sun  Dinner     4

# %%
tips_data_10[(tips_data_10['sex'] == 'Male') & (tips_data_10['total_bill'] == tips_data_10['total_bill'].min())]
# Out:
#    total_bill  tip   sex smoker  day    time  size
# 6        8.77  2.0  Male     No  Sun  Dinner     2

# %%
sns.boxplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')

# %%
tips_data_10[tips_data_10['sex']=='Male'].describe()
# Out:
#        total_bill       tip      size
# count    9.000000  9.000000  9.000000
# mean    17.340000  2.800000  2.666667
# std      7.001357  1.031916  0.866025
# min      8.770000  1.660000  2.000000
# 25%     10.340000  1.960000  2.000000
# 50%     15.040000  3.120000  2.000000
# 75%     23.680000  3.310000  3.000000
# max     26.880000  4.710000  4.000000

# %%
tips_data_10[tips_data_10['sex']=='Female'].describe()
# Out:
#        total_bill       tip      size
# count    2.000000  2.000000  2.000000
# mean    20.790000  2.310000  3.000000
# std      5.374012  1.838478  1.414214
# min     16.990000  1.010000  2.000000
# 25%     18.890000  1.660000  2.500000
# 50%     20.790000  2.310000  3.000000
# 75%     22.690000  2.960000  3.500000
# max     24.590000  3.610000  4.000000

# %%
sns.boxplot(x='day' ,y='tip', data=tips_data_10, hue='sex')

# %%
tips_data_10[tips_data_10['sex']=='Female'].describe()
# Out:
#        total_bill       tip      size
# count    2.000000  2.000000  2.000000
# mean    20.790000  2.310000  3.000000
# std      5.374012  1.838478  1.414214
# min     16.990000  1.010000  2.000000
# 25%     18.890000  1.660000  2.500000
# 50%     20.790000  2.310000  3.000000
# 75%     22.690000  2.960000  3.500000
# max     24.590000  3.610000  4.000000

# %%
tips_data_10[tips_data_10['sex']=='Male'].describe()
# Out:
#        total_bill       tip      size
# count    9.000000  9.000000  9.000000
# mean    17.340000  2.800000  2.666667
# std      7.001357  1.031916  0.866025
# min      8.770000  1.660000  2.000000
# 25%     10.340000  1.960000  2.000000
# 50%     15.040000  3.120000  2.000000
# 75%     23.680000  3.310000  3.000000
# max     26.880000  4.710000  4.000000

# %%
sns.violinplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')

# %%
sns.swarmplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')

# %%
sns.scatterplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')

# %%
sns.catplot(x='day' ,y='total_bill', data=tips_data_10, hue='sex')
